# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Updated path to the actual location of your CSV file
file_path = r"C:\Users\user\OneDrive\Desktop\Google Data Analytic Certification File\Antimatidata Project\2017_Yellow_Taxi_Trip_Data.csv"

# Print the file path to verify it is correct
print("File path being used:", file_path)

# Check if the file exists
if os.path.exists(file_path):
    # Load the CSV file into a DataFrame
    df = pd.read_csv(file_path)
    # Display the first few rows of the DataFrame
    print(df.head())
else:
    print("File not found. Please check the path.")
# Out:
# File path being used: C:\Users\user\OneDrive\Desktop\Google Data Analytic Certification File\Antimatidata Project\2017_Yellow_Taxi_Trip_Data.csv
#    Unnamed: 0  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0    24870114         2       3/25/2017 8:55        3/25/2017 9:09
# 1    35634249         1      4/11/2017 14:53       4/11/2017 15:19
# 2   106203690         1      12/15/2017 7:26       12/15/2017 7:34
# 3    38942136         2       5/7/2017 13:17        5/7/2017 13:48
# 4    30841670         2      4/15/2017 23:32       4/15/2017 23:49
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0                6           3.34           1                  N
# 1                1           1.80           1                  N
# 2                1           1.00           1                  N
# 3                1           3.70           1                  N
# 4                1           4.37           1                  N
#
# ...

# %%
 print(df.tail())
# Out:
#        Unnamed: 0  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 22694    14873857         2      2/24/2017 17:37       2/24/2017 17:40
# 22695    66632549         2       8/6/2017 16:43        8/6/2017 17:24
# 22696    74239933         2       9/4/2017 14:54        9/4/2017 14:58
# 22697    60217333         2      7/15/2017 12:56       7/15/2017 13:08
# 22698    17208911         1       3/2/2017 13:02        3/2/2017 13:16
#
#        passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 22694                3           0.61           1                  N
# 22695                1          16.71           2                  N
# 22696                1           0.42           1                  N
# 22697                1           2.36           1                  N
# 22698                1           2.10           1                  N
#
#        PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  \
# ...

# %%
import pandas as pd

# Assuming 'df' is your DataFrame
missing_values_per_column = df.isna().sum()
print("Missing values per column:")
print(missing_values_per_column)
# Out:
# Missing values per column:
# Unnamed: 0               0
# VendorID                 0
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# trip_distance            0
# RatecodeID               0
# store_and_fwd_flag       0
# PULocationID             0
# DOLocationID             0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# dtype: int64

# %%
# Dictionary defining the units for each variable
variable_units = {
    'pickup_datetime': 'Timestamp (YYYY-MM-DD HH:MM:SS)',
    'passenger_count': 'Count (integer)',
    'trip_distance': 'Miles (floating-point number)',
    'pickup_longitude': 'Degrees (floating-point number)',
    'pickup_latitude': 'Degrees (floating-point number)',
    'dropoff_longitude': 'Degrees (floating-point number)',
    'dropoff_latitude': 'Degrees (floating-point number)',
    'extra': 'Dollars (floating-point number)',
    'mta_tax': 'Dollars (floating-point number)',
    'tolls_amount': 'Dollars (floating-point number)',
    'rate_code': 'Categorical (integer)',
    'fare_amount': 'Dollars (floating-point number)',
}

# Function to print the variable units in a readable format
def print_variable_units(units_dict):
    print("Variable Units:")
    for variable, unit in units_dict.items():
        print(f"{variable}: {unit}")

# Call the function to display the units
print_variable_units(variable_units)
# Out:
# Variable Units:
# pickup_datetime: Timestamp (YYYY-MM-DD HH:MM:SS)
# passenger_count: Count (integer)
# trip_distance: Miles (floating-point number)
# pickup_longitude: Degrees (floating-point number)
# pickup_latitude: Degrees (floating-point number)
# dropoff_longitude: Degrees (floating-point number)
# dropoff_latitude: Degrees (floating-point number)
# extra: Dollars (floating-point number)
# mta_tax: Dollars (floating-point number)
# tolls_amount: Dollars (floating-point number)
# rate_code: Categorical (integer)
# fare_amount: Dollars (floating-point number)

# %%
import os
import datetime
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Verify the current working directory
print("Current working directory:", os.getcwd())

# Update this path to the actual location of your CSV file
file_path = "C:/Users/user/OneDrive/Desktop/Google Data Analytic Certification File/2017_Yellow_Taxi_Trip_Data.csv"

# Verify if the file exists
if os.path.exists(file_path):
    print(f"File found: {file_path}")
    # Read the CSV file
    df = pd.read_csv(file_path)
    # Print the head of the DataFrame
    print(df.head())
else:
    print(f"File not found: {file_path}")
# Out:
# Current working directory: C:\Users\user
# File found: C:/Users/user/OneDrive/Desktop/Google Data Analytic Certification File/2017_Yellow_Taxi_Trip_Data.csv
#    Unnamed: 0  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0    24870114         2       3/25/2017 8:55        3/25/2017 9:09
# 1    35634249         1      4/11/2017 14:53       4/11/2017 15:19
# 2   106203690         1      12/15/2017 7:26       12/15/2017 7:34
# 3    38942136         2       5/7/2017 13:17        5/7/2017 13:48
# 4    30841670         2      4/15/2017 23:32       4/15/2017 23:49
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0                6           3.34           1                  N
# 1                1           1.80           1                  N
# 2                1           1.00           1                  N
# 3                1           3.70           1                  N
# 4                1           4.37           1                  N
#
# ...

# %%
print(df.describe())
# Out:
#          Unnamed: 0      VendorID  passenger_count  trip_distance  \
# count  2.269900e+04  22699.000000     22699.000000   22699.000000
# mean   5.675849e+07      1.556236         1.642319       2.913313
# std    3.274493e+07      0.496838         1.285231       3.653171
# min    1.212700e+04      1.000000         0.000000       0.000000
# 25%    2.852056e+07      1.000000         1.000000       0.990000
# 50%    5.673150e+07      2.000000         1.000000       1.610000
# 75%    8.537452e+07      2.000000         2.000000       3.060000
# max    1.134863e+08      2.000000         6.000000      33.960000
#
#          RatecodeID  PULocationID  DOLocationID  payment_type   fare_amount  \
# count  22699.000000  22699.000000  22699.000000  22699.000000  22699.000000
# mean       1.043394    162.412353    161.527997      1.336887     13.026629
# std        0.708391     66.633373     70.139691      0.496211     13.243791
# ...

# %%
import pandas as pd

# Load data
file_path = "C:/Users/user/OneDrive/Desktop/Google Data Analytic Certification File/Antimatidata Project/2017_Yellow_Taxi_Trip_Data.csv"
df = pd.read_csv(file_path)

# Print column names to check for 'pickup_datetime'
print("Column names in the DataFrame:")
print(df.columns)

# Display the first few rows to check the data and column names
print("First few rows of the DataFrame:")
print(df.head())

# If 'pickup_datetime' exists, proceed with extraction
if 'pickup_datetime' in df.columns:
    # Extract date-time features
    df['pickup_datetime'] = pd.to_datetime(df['pickup_datetime'])
    df['pickup_hour'] = df['pickup_datetime'].dt.hour
    df['pickup_day_of_week'] = df['pickup_datetime'].dt.dayofweek
    df['pickup_day'] = df['pickup_datetime'].dt.day

    # Calculate geographical distance using Haversine formula
    def haversine_distance(lat1, lon1, lat2, lon2):
        # Convert latitude and longitude from degrees to radians
        lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])
        
        # Haversine formula
        dlat = lat2 - lat1
        dlon = lon2 - lon1
        a = np.sin(dlat / 2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon / 2)**2
        c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1 - a))
        r = 3958.8  # Radius of Earth in miles
        return r * c

    df['trip_distance_calculated'] = df.apply(
        lambda row: haversine_distance(
            row['pickup_latitude'], row['pickup_longitude'],
            row['dropoff_latitude'], row['dropoff_longitude']
        ), axis=1
    )

    # Select relevant features
    features = [
        'pickup_hour', 'pickup_day_of_week', 'pickup_day',
        'passenger_count', 'trip_distance', 'extra', 'mta_tax', 'tolls_amount', 'fare_amount', 'trip_distance_calculated'
    ]

    # Create a new DataFrame with selected features
    df_features = df[features]

    # Display the first few rows of the DataFrame with selected features
    print(df_features.head())
else:
    print("The column 'pickup_datetime' does not exist in the DataFrame. Please check the column names.")
# Out:
# Column names in the DataFrame:
# Index(['Unnamed: 0', 'VendorID', 'tpep_pickup_datetime',
#        'tpep_dropoff_datetime', 'passenger_count', 'trip_distance',
#        'RatecodeID', 'store_and_fwd_flag', 'PULocationID', 'DOLocationID',
#        'payment_type', 'fare_amount', 'extra', 'mta_tax', 'tip_amount',
#        'tolls_amount', 'improvement_surcharge', 'total_amount'],
#       dtype='object')
# First few rows of the DataFrame:
#    Unnamed: 0  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0    24870114         2       3/25/2017 8:55        3/25/2017 9:09
# 1    35634249         1      4/11/2017 14:53       4/11/2017 15:19
# 2   106203690         1      12/15/2017 7:26       12/15/2017 7:34
# 3    38942136         2       5/7/2017 13:17        5/7/2017 13:48
# 4    30841670         2      4/15/2017 23:32       4/15/2017 23:49
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0                6           3.34           1                  N
# ...

# %%
variable_units = {
    'pickup_datetime': 'Timestamp (YYYY-MM-DD HH:MM:SS)',
    'passenger_count': 'Count (integer)',
    'trip_distance': 'Miles (floating-point number)',
    'pickup_longitude': 'Degrees (floating-point number)',
    'pickup_latitude': 'Degrees (floating-point number)',
    'dropoff_longitude': 'Degrees (floating-point number)',
    'dropoff_latitude': 'Degrees (floating-point number)',
    'extra': 'Dollars (floating-point number)',
    'mta_tax': 'Dollars (floating-point number)',
    'tolls_amount': 'Dollars (floating-point number)',
    'rate_code': 'Categorical (integer)',
    'fare_amount': 'Dollars (floating-point number)',
}

# Function to print the variable units in a readable format
def print_variable_units(units_dict):
    print("Variable Units:")
    for variable, unit in units_dict.items():
        print(f"{variable}: {unit}")

# Call the function to display the units
print_variable_units(variable_units)
# Out:
# Variable Units:
# pickup_datetime: Timestamp (YYYY-MM-DD HH:MM:SS)
# passenger_count: Count (integer)
# trip_distance: Miles (floating-point number)
# pickup_longitude: Degrees (floating-point number)
# pickup_latitude: Degrees (floating-point number)
# dropoff_longitude: Degrees (floating-point number)
# dropoff_latitude: Degrees (floating-point number)
# extra: Dollars (floating-point number)
# mta_tax: Dollars (floating-point number)
# tolls_amount: Dollars (floating-point number)
# rate_code: Categorical (integer)
# fare_amount: Dollars (floating-point number)

# %%
print("Missing values:\n", df.isnull().sum())
# Out:
# Missing values:
#  Unnamed: 0               0
# VendorID                 0
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# trip_distance            0
# RatecodeID               0
# store_and_fwd_flag       0
# PULocationID             0
# DOLocationID             0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# dtype: int64

# %%
print("Summary statistics:\n", df.describe())
# Out:
# Summary statistics:
#           Unnamed: 0      VendorID  passenger_count  trip_distance  \
# count  2.269900e+04  22699.000000     22699.000000   22699.000000
# mean   5.675849e+07      1.556236         1.642319       2.913313
# std    3.274493e+07      0.496838         1.285231       3.653171
# min    1.212700e+04      1.000000         0.000000       0.000000
# 25%    2.852056e+07      1.000000         1.000000       0.990000
# 50%    5.673150e+07      2.000000         1.000000       1.610000
# 75%    8.537452e+07      2.000000         2.000000       3.060000
# max    1.134863e+08      2.000000         6.000000      33.960000
#
#          RatecodeID  PULocationID  DOLocationID  payment_type   fare_amount  \
# count  22699.000000  22699.000000  22699.000000  22699.000000  22699.000000
# mean       1.043394    162.412353    161.527997      1.336887     13.026629
# std        0.708391     66.633373     70.139691      0.496211     13.243791
# ...

# %%
import pandas as pd

# Load data
file_path = "C:/Users/user/OneDrive/Desktop/Google Data Analytic Certification File/2017_Yellow_Taxi_Trip_Data.csv"
df = pd.read_csv(file_path)

# Print the column names to identify the correct names
print("Column names in the dataset:")
print(df.columns)

# Update the expected data types based on the actual column names
# Assuming the columns have similar names but possibly with different casing or formatting
expected_dtypes = {
    'tpep_pickup_datetime': 'datetime64[ns]',
    'passenger_count': 'int64',
    'trip_distance': 'float64',
    'pickup_longitude': 'float64',
    'pickup_latitude': 'float64',
    'dropoff_longitude': 'float64',
    'dropoff_latitude': 'float64',
    'extra': 'float64',
    'mta_tax': 'float64',
    'tolls_amount': 'float64',
    'rate_code': 'int64',
    'fare_amount': 'float64'
}

# Convert pickup_datetime to datetime (using the actual column name from the dataset)
if 'tpep_pickup_datetime' in df.columns:
    df['tpep_pickup_datetime'] = pd.to_datetime(df['tpep_pickup_datetime'], errors='coerce')

# Check the data types
actual_dtypes = df.dtypes

# Compare the actual data types with the expected data types
for column, expected_dtype in expected_dtypes.items():
    if column in actual_dtypes:
        actual_dtype = actual_dtypes[column]
        if actual_dtype != expected_dtype:
            print(f"Column '{column}' has type '{actual_dtype}' but expected type is '{expected_dtype}'.")
    else:
        print(f"Column '{column}' is missing from the dataset.")

# Output the data types for reference
print("\nActual data types:")
print(actual_dtypes)
# Out:
# Column names in the dataset:
# Index(['Unnamed: 0', 'VendorID', 'tpep_pickup_datetime',
#        'tpep_dropoff_datetime', 'passenger_count', 'trip_distance',
#        'RatecodeID', 'store_and_fwd_flag', 'PULocationID', 'DOLocationID',
#        'payment_type', 'fare_amount', 'extra', 'mta_tax', 'tip_amount',
#        'tolls_amount', 'improvement_surcharge', 'total_amount'],
#       dtype='object')
# Column 'pickup_longitude' is missing from the dataset.
# Column 'pickup_latitude' is missing from the dataset.
# Column 'dropoff_longitude' is missing from the dataset.
# Column 'dropoff_latitude' is missing from the dataset.
# Column 'rate_code' is missing from the dataset.
#
# Actual data types:
# Unnamed: 0                        int64
# VendorID                          int64
# tpep_pickup_datetime     datetime64[ns]
# tpep_dropoff_datetime            object
# passenger_count                   int64
# trip_distance                   float64
# RatecodeID                        int64
# ...

# %%
print("First few rows of the dataset:")
print(df.head())

# Display the column names and data types
print("\nColumn names and data types:")
print(df.dtypes)

# Check for missing values
print("\nMissing values per column:")
print(df.isnull().sum())

# Check for basic statistics to identify any anomalies
print("\nBasic statistics:")
print(df.describe())
# Out:
# First few rows of the dataset:
#    Unnamed: 0  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0    24870114         2  2017-03-25 08:55:00        3/25/2017 9:09
# 1    35634249         1  2017-04-11 14:53:00       4/11/2017 15:19
# 2   106203690         1  2017-12-15 07:26:00       12/15/2017 7:34
# 3    38942136         2  2017-05-07 13:17:00        5/7/2017 13:48
# 4    30841670         2  2017-04-15 23:32:00       4/15/2017 23:49
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0                6           3.34           1                  N
# 1                1           1.80           1                  N
# 2                1           1.00           1                  N
# 3                1           3.70           1                  N
# 4                1           4.37           1                  N
#
#    PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  \
# ...

# %%
# Check unique values in categorical columns
categorical_columns = ['RatecodeID', 'payment_type']
for column in categorical_columns:
    if column in df.columns:
        print(f"\nUnique values in {column}:")
        print(df[column].unique())

# Checking date range for pickup and dropoff times
if 'tpep_pickup_datetime' in df.columns and 'tpep_dropoff_datetime' in df.columns:
    print("\nDate range for pickup and dropoff times:")
    print(f"Pickup times: {df['tpep_pickup_datetime'].min()} to {df['tpep_pickup_datetime'].max()}")
    print(f"Dropoff times: {df['tpep_dropoff_datetime'].min()} to {df['tpep_dropoff_datetime'].max()}")

# Checking the range for geographical coordinates
if 'pickup_latitude' in df.columns and 'pickup_longitude' in df.columns:
    print("\nRange for pickup geographical coordinates:")
    print(f"Latitude: {df['pickup_latitude'].min()} to {df['pickup_latitude'].max()}")
    print(f"Longitude: {df['pickup_longitude'].min()} to {df['pickup_longitude'].max()}")

if 'dropoff_latitude' in df.columns and 'dropoff_longitude' in df.columns:
    print("\nRange for dropoff geographical coordinates:")
    print(f"Latitude: {df['dropoff_latitude'].min()} to {df['dropoff_latitude'].max()}")
    print(f"Longitude: {df['dropoff_longitude'].min()} to {df['dropoff_longitude'].max()}")
# Out:
# Unique values in RatecodeID:
# [ 1  2  5  3  4 99]
#
# Unique values in payment_type:
# [1 2 3 4]
#
# Date range for pickup and dropoff times:
# Pickup times: 2017-01-01 00:08:00 to 2017-12-31 23:45:00
# Dropoff times: 1/1/2017 0:17 to 9/9/2017 8:01

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Updated path to the actual location of your CSV file
file_path = r"C:\Users\user\OneDrive\Desktop\Google Data Analytic Certification File\Antimatidata Project\2017_Yellow_Taxi_Trip_Data.csv"

# Print the file path to verify it is correct
print("File path being used:", file_path)

# Convert datetime columns to datetime type
df['tpep_pickup_datetime'] = pd.to_datetime(df['tpep_pickup_datetime'])
df['tpep_dropoff_datetime'] = pd.to_datetime(df['tpep_dropoff_datetime'])

# Basic data cleaning (e.g., removing negative fare amounts)
df = df[df['fare_amount'] > 0]

# Visualizing the distribution of fare amounts
plt.figure(figsize=(10, 6))
sns.histplot(df['fare_amount'], kde=True, bins=50)
plt.title('Distribution of Fare Amounts')
plt.xlabel('Fare Amount')
plt.ylabel('Frequency')
plt.show()
# Out:
# File path being used: C:\Users\user\OneDrive\Desktop\Google Data Analytic Certification File\Antimatidata Project\2017_Yellow_Taxi_Trip_Data.csv

# %%
# Visualizing outliers in fare amounts using a box plot
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['fare_amount'])
plt.title('Box Plot of Fare Amounts')
plt.xlabel('Fare Amount')
plt.show()

# %%
# Scatter plot of trip distance vs. fare amount
plt.figure(figsize=(10, 6))
sns.scatterplot(x='trip_distance', y='fare_amount', data=df)
plt.title('Trip Distance vs. Fare Amount')
plt.xlabel('Trip Distance (miles)')
plt.ylabel('Fare Amount')
plt.show()

# %%
# Visualizing the relationship between fare amount and passenger count
plt.figure(figsize=(10, 6))
sns.boxplot(x='passenger_count', y='fare_amount', data=df)
plt.title('Fare Amount by Passenger Count')
plt.xlabel('Passenger Count')
plt.ylabel('Fare Amount')
plt.show()

# %%
# Correlation heatmap to understand relationships between variables
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10080\2028135815.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, cmap='coolwarm', linewidths=0.5)

# %%
# Additional visualization: bar plot for average fare amount by payment type
plt.figure(figsize=(10, 6))
sns.barplot(x='payment_type', y='fare_amount', data=df, estimator=lambda x: x.mean())
plt.title('Average Fare Amount by Payment Type')
plt.xlabel('Payment Type')
plt.ylabel('Average Fare Amount')
plt.show()
